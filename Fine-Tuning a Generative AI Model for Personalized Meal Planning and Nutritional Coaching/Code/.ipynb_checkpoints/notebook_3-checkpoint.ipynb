# %% [markdown]
# <center>
#
# ## Fine-Tuning a Generative AI Model for
# ## Personalized Meal Planning and Nutritional Coaching
# ## Arulsree Mozhi, TS
#
# </center>

# %%
pip install openai
# Out:
# Requirement already satisfied: openai in c:\users\say_f\anaconda3\lib\site-packages (2.6.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\say_f\anaconda3\lib\site-packages (from openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\say_f\anaconda3\lib\site-packages (from openai) (1.8.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\say_f\anaconda3\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\say_f\anaconda3\lib\site-packages (from openai) (0.11.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\say_f\anaconda3\lib\site-packages (from openai) (2.12.4)
# Requirement already satisfied: sniffio in c:\users\say_f\anaconda3\lib\site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\say_f\anaconda3\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\say_f\anaconda3\lib\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\say_f\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.4)
# Requirement already satisfied: certifi in c:\users\say_f\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\say_f\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\say_f\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\say_f\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\say_f\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\say_f\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: colorama in c:\users\say_f\anaconda3\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.environ["OPENAI_API_KEY"] = "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"

# %%
from openai import OpenAI
client = OpenAI()

response = client.chat.completions.create(
    model="ft:gpt-3.5-turbo-0125:personal::CXcXRFZv",
    messages=[
        {"role": "system", "content": "You are a helpful nutrition assistant."},
        {"role": "user", "content": "Create a high-protein vegetarian dinner."}
    ]
)

print(response.choices[0].message.content)
# Out:
# Quinoa and black bean stuffed peppers: Roast bell peppers, fill with cooked quinoa, black beans, diced tomatoes, corn, and sprinkle with cheese. Bake until peppers are tender.
